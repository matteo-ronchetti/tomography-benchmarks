# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import glob

results = [json.load(open(p)) for p in glob.glob("*_results.json")]
print(results)
# Out:
# [{'library': 'TorchRadon half', 'batch_size': 32, 'warmup': 50, 'repeats': 250, 'gpu': 'GeForce GTX 1650', 'results': [{'task': 'parallel forward', 'num angles': 256, 'det count': 256, 'time': 0.4983847141265869, 'fps': 16051.85667465725}, {'task': 'parallel backward', 'num angles': 256, 'det count': 256, 'time': 0.5083968639373779, 'fps': 15735.738293195696}, {'task': 'fanbeam forward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 0.47966814041137695, 'fps': 16678.197541197907}, {'task': 'fanbeam backward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 0.4881608486175537, 'fps': 16388.04099643711}]}, {'library': 'pyronn', 'batch_size': 32, 'warmup': 50, 'repeats': 250, 'gpu': 'GeForce GTX 1650', 'results': [{'task': 'parallel forward', 'num angles': 256, 'det count': 256, 'time': 18.54387640953064, 'fps': 431.4092600341315}, {'task': 'parallel backward', 'num angles': 256, 'det count': 256, 'time': 3.9722940921783447, 'fps': 2013.949575322839}, {'task': 'fanbeam forward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 20.46932625770569, 'fps': 390.82869163748836}, {'task': 'fanbeam backward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 8.142483711242676, 'fps': 982.5011978782417}]}, {'library': 'TorchRadon', 'batch_size': 32, 'warmup': 50, 'repeats': 250, 'gpu': 'GeForce GTX 1650', 'results': [{'task': 'parallel forward', 'num angles': 256, 'det count': 256, 'time': 1.220390796661377, 'fps': 6555.277229134798}, {'task': 'parallel backward', 'num angles': 256, 'det count': 256, 'time': 1.2455790042877197, 'fps': 6422.715839349567}, {'task': 'fanbeam forward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 1.2151730060577393, 'fps': 6583.424714110114}, {'task': 'fanbeam backward', 'num angles': 256, 'det count': 256, 'source distance': 256, 'detector distance': 256, 'time': 1.2279400825500488, 'fps': 6514.9758637949935}]}]

# %%
title = results[0]["gpu"]
tasks = ["parallel forward", "parallel backward", "fanbeam forward", "fanbeam backward"]
libraries = ["pyronn", "TorchRadon", "TorchRadon half"]

fps = np.zeros((len(libraries), len(tasks)))

for res in results:
    if res["library"] in libraries:
        y = libraries.index(res["library"])
        for line in res["results"]:
            if line["task"] in tasks:
                x = tasks.index(line["task"])
                fps[y, x] = line["fps"]

print(fps)
# Out:
# [[  431.40926003  2013.94957532   390.82869164   982.50119788]
#  [ 6555.27722913  6422.71583935  6583.42471411  6514.97586379]
#  [16051.85667466 15735.7382932  16678.1975412  16388.04099644]]

# %%
labels = tasks


x = np.arange(len(tasks))  # the label locations
spacing = 0.0
width = (1.0 - spacing) / fps.shape[1]  # the width of the bars

params = {
    'font.size': 12,
    "figure.figsize": [10, 8]
}
plt.rcParams.update(params)

fig, ax = plt.subplots()
rects = []
for i, lib in enumerate(libraries):
    px = x + (i - len(libraries)//2)*width
    rects.append(ax.bar(px, fps[i], width, label=lib))
    
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images/second')
ax.set_title(title)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(bbox_to_anchor=(0.5, 1), loc='upper center', ncol=len(libraries))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f"{int(np.round(height))}",
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 1),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

for rect in rects:
    autolabel(rect)

plt.margins(0.05, 0.15)
